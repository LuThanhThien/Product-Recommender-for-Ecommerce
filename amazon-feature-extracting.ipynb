# %% [markdown]
# # Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import plotly.express as px
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from wordcloud import WordCloud
import time
import re

input_path = 'inputs\\data\\amazon'
output_path = 'outputs\\data\\amazon'

# %% [markdown]
# # Data overview

# %%
# Load data 
df = pd.read_csv(f'{input_path}\\amazon.csv')

# %%
productTable = df[['product_id', 'product_name', 'about_product', 'discounted_price', 'actual_price']]

# %%
len(df)
# Out:
# 1465

# %% [markdown]
# Those needed to be cleaned:
# - Drop duplicates
# - Money sign drop
# - Negative prices?
# - Clean product name
# - clean category
# - clean about product
# - clean user id and user name
# - review content and review title
# - drop image link and product link (these used for website)

# %%
df['rating'].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
df['rating_count'].unique()
# Out:
# array(['24,269', '43,994', '7,928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %%
df_clean = df.copy()

# %%
def print_end():
    print('-------------------------------------------------------------')

# %%
def drop_duplicates(df):
    print('Drop duplicates processing...')
    start = time.time()
    num_duplicates = len(df[df.duplicated(keep=False)])
    if num_duplicates > 0:
        print('Found {:d} duplicate rows'.format(num_duplicates))
        # Drop duplicates
        df = df.drop_duplicates()
    else:
        print('Found no duplicate.')
    end = time.time()
    print('End drop duplicates. Finished in {0:.3f}s.'.format(end - start))
    print_end()

# %%
def number_taker(string):

    # if already number
    if not isinstance(string, str):
        return string
    
    # take numbers
    numbers = re.findall(r'\d+\.\d+|\d+', string)
    numbers = list(map(str, numbers))
    # print(numbers)
    
    if len(numbers)>=1:
        # map numbers
        result = float(''.join(map(str, numbers)))
        return result
    
    else:  
        return None
    
print(number_taker('$334,2.99'))
# Out:
# 3342.99

# %%
def numeric_processing(df):
    print('Numeric processing...')

    start=time.time()
    df['discounted_price'] = df['discounted_price'].apply(number_taker)
    df['actual_price'] = df['actual_price'].apply(number_taker)
    df['discount_percentage'] = df['discount_percentage'].apply(number_taker)/100
    df['rating'] = df['rating'].apply(number_taker)
    df['rating_count'] = df['rating_count'].apply(number_taker)
    end=time.time()

    print('Processing price successfully. Finished in {:.3f}s'.format(end-start))
    print_end()

# %%
# drop duplicates
drop_duplicates(df_clean)
# Out:
# Drop duplicates processing...
# Found no duplicate.
# End drop duplicates. Finished in 0.023s.
# -------------------------------------------------------------

# %%
numeric_processing(df_clean)
# Out:
# Numeric processing...
# Processing price successfully. Finished in 0.022s
# -------------------------------------------------------------

# %%
df_clean.loc[df_clean['rating'].isna()]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# 1279        2499.0                 0.16     NaN         992.0
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
#                                          review_content  \
# 1279  Does the job well,doesn't work on sand. though...
#
#                                                img_link  \
# 1279  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 1279  https://www.amazon.in/Eureka-Forbes-Vacuum-Cle...

# %%
# changing rating for nan
df_clean['rating'] = df_clean['rating'].fillna(4.0)

# %%
# Show dfset information
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: float64(5), object(11)
# memory usage: 183.2+ KB

# %%
# Summarize the training set
df_clean.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635             0.476915     4.096519
# std         6944.304394   10874.826864             0.216359     0.291585
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1650.000000             0.500000     4.100000
# 75%         1999.000000    4295.000000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %%
def fix_strings(string):
    result = re.split(r'(?=[A-Z&])', string)
    result = ' '.join(result)
    return result

# %%
def split_category(df):
    print('Splitting category...')

    start=time.time()
    catsplit = df['category'].str.split('|', expand=True)
    catsplit = catsplit.rename(columns={0:'category_1', 1:'category_2'})

    # adding only category_1 and category_2
    if 'category_1' not in df.columns:
        df['category_1'] = catsplit['category_1']
        df['category_1'] = df['category_1'].apply(fix_strings)
    if 'category_2' not in df.columns:
        df['category_2'] = catsplit['category_2']
        df['category_2'] = df['category_2'].apply(fix_strings)
    if 'category' in df.columns:
        df.drop(columns='category', inplace=True)

    end=time.time()
    print('End split category. Finished in {0:.3f}s.'.format(end - start))
    print_end()

# %%
def price_difference(df):
    print('Calculating price differnce...')

    start = time.time()
    if 'price_difference' not in df.columns:
        df['price_difference'] = df['actual_price'] - df['discounted_price']

    end=time.time()
    print('End calculating price difference. Finished in {0:.3f}s.'.format(end - start))
    print_end()

# %%
split_category(df_clean)
# Out:
# Splitting category...
# End split category. Finished in 0.025s.
# -------------------------------------------------------------

# %%
def remove_id_space(df):
    df['product_id'].str.strip()
    df['user_id'].str.strip()

# %%
# remove space
df_clean['product_id'].str.strip()
# Out:
# 0       B07JW9H4J1
# 1       B098NS6PVG
# 2       B096MSW6CT
# 3       B08HDJ86NZ
# 4       B08CF3B7N1
#            ...
# 1460    B08L7J3T31
# 1461    B01M6453MB
# 1462    B009P2LIL4
# 1463    B00J5DYCCA
# 1464    B01486F4G6
# Name: product_id, Length: 1465, dtype: object

# %%
def rating_score(df):
    print('Rating score processing...')

    start=time.time()
    def score_cat(score):
        if score < 2.0 : return 'Poor'
        elif score < 3.0 : return 'Below Average'
        elif score < 4.0 : return 'Average'
        elif score < 5.0 : return 'Above Average'
        elif score == 5.0 : return 'Excellent'

    if 'rating_score' not in df.columns:
        df['rating_score'] = df['rating'].apply(score_cat)
        df['rating_score'] = df['rating_score'].astype('category')
        df['rating_score'] = df['rating_score'].cat.reorder_categories(['Below Average', 'Average', 'Above Average', 'Excellent'], ordered=True)

    end=time.time()
    print('End split category. Finished in {0:.3f}s.'.format(end - start))
    print_end()

# %%
rating_score(df_clean)
# Out:
# Rating score processing...
# End split category. Finished in 0.004s.
# -------------------------------------------------------------

# %%
price_difference(df_clean)
# Out:
# Calculating price differnce...
# End calculating price difference. Finished in 0.000s.
# -------------------------------------------------------------

# %%
def merge_dataframe(data_list, on=None, suffixes=('_x', '_y')):
    if on==None:
        raise AttributeError('Must be specify the merging key!')

    df_merge = data_list[0]
    for df in data_list[1:]:
        df_merge = df_merge.merge(df, on=on, how='left', suffixes=suffixes)
        
    return df_merge

# %%
def user_info(df):
    # split user_id
    reviewer_id_split = df['user_id'].str.split(',', expand=False)
    reviewer_id_exp = reviewer_id_split.explode()
    reviewer_id_clean = reviewer_id_exp.reset_index(drop=True)

    # split user_name
    reviewer_name_split = df['user_name'].str.split(',', expand=False)
    review_name_exp = reviewer_name_split.explode()
    reviewer_name_clean = review_name_exp.reset_index(drop=True)

    reviewer_id_clean = pd.DataFrame(reviewer_id_clean)
    reviewer_name_clean = pd.DataFrame(reviewer_name_clean)

    return pd.merge(reviewer_id_clean, reviewer_name_clean, left_index=True, right_index=True)

# %%
def seperate_user(df):
	df_new = df.copy()
	df_new['user_id'] = df_new['user_id'].str.split(',')
	df_new['user_name'] = df_new['user_name'].str.split(',')
	return df_new.explode(['user_id','user_name'])

# %%
def count_commas(string):
    return string.count(',')

# %%
df_clean['is_same'] = df_clean['user_id'].apply(count_commas).astype(int) - df_clean['user_name'].apply(count_commas).astype(int)
df_clean = df_clean.loc[df_clean.is_same!=-1]
df_clean.drop(columns=['is_same'], inplace=True)
df_clean = seperate_user(df_clean)

# %%
productTable = df_clean[['product_id', 'product_name', 'about_product', 'category_1', 'category_2', 'discounted_price', 'actual_price', 
                         'discount_percentage', 'rating', 'rating_count', 'img_link', 'product_link']]

# %%
productTable.drop_duplicates(subset=['product_name'], keep='first', inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_4108\403160633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   productTable.drop_duplicates(subset=['product_name'], keep='first', inplace=True)

# %%
productTable.to_csv('outputs\\data\\amazon\\amazon-product.csv', index=False)

# %%
user_count = df_clean.user_id.value_counts().reset_index()
user_count.loc[user_count['count']!=1]
# Out:
#                            user_id  count
# 0     AE55KTFVNXYFD5FPYWP2OUPEYNPQ     11
# 1     AG5DWPD54QGSLWJ6QUFERLPNAX4Q     11
# 2     AEBWA5I4QFCA3P3OBEPMELBGN4GQ     10
# 3     AHMGAC6QM62UXNEOCZIHLHSXPP2Q     10
# 4     AFHROSCGIXUPV3FYQ7H5QOD46Q7Q     10
# ...                            ...    ...
# 1290  AGYTCTSUZJJZTK2XVADTQI5MYUFQ      2
# 1291  AELBYFRFAGLMXQQJKVDUWO7QX2VQ      2
# 1292  AGKNFVSMZCSEFHPASWFBOIYKRZJA      2
# 1293  AERBQW23ELEQZRWXWOW5EFQ2AA7Q      2
# 1294  AE6T7WGZSJSYC6C44JF6AJLJDOCA      2
#
# [1295 rows x 2 columns]

# %%
data_clean = pd.read_csv(f'{output_path}\\Sales_Amazon_Cleaned_final.csv')

# %%
data_clean
# Out:
#         Unnamed: 0                       user_id  product_id  \
# 0                0  AG3D6O4STAQKAY2UVGEUV46KN35Q  B07JW9H4J1
# 1                1  AG3D6O4STAQKAY2UVGEUV46KN35Q  B07JW9H4J1
# 2                2  AG3D6O4STAQKAY2UVGEUV46KN35Q  B07JW9H4J1
# 3                3  AG3D6O4STAQKAY2UVGEUV46KN35Q  B07JW9H4J1
# 4                4  AG3D6O4STAQKAY2UVGEUV46KN35Q  B07JW9H4J1
# ...            ...                           ...         ...
# 151804      151804  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ  B01486F4G6
# 151805      151805  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ  B01486F4G6
# 151806      151806  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ  B01486F4G6
# 151807      151807  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ  B01486F4G6
# 151808      151808  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ  B01486F4G6
#
#                user_name                                       product_name  \
# 0                  Manav  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1                  Manav  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2                  Manav  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3           Adarsh gupta  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4           Adarsh gupta  Wayona Nylon Braided USB to Lightning Fast Cha...
# ...                  ...                                                ...
# 151804           PARDEEP  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 151805  Anindya Pramanik  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 151806       Vikas Singh  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 151807   Harshada Pimple  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 151808            Saw a.  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#         discounted_price  actual_price  discount_percentage  rating  \
# 0                  399.0        1099.0                 0.64     4.2
# 1                  399.0        1099.0                 0.64     4.2
# 2                  399.0        1099.0                 0.64     4.2
# 3                  399.0        1099.0                 0.64     4.2
# 4                  399.0        1099.0                 0.64     4.2
# ...                  ...           ...                  ...     ...
# 151804            2863.0        3690.0                 0.22     4.3
# 151805            2863.0        3690.0                 0.22     4.3
# 151806            2863.0        3690.0                 0.22     4.3
# 151807            2863.0        3690.0                 0.22     4.3
# 151808            2863.0        3690.0                 0.22     4.3
#
#         rating_count               category_1                 category_2  \
# 0            24269.0  Computers & Accessories  Accessories & Peripherals
# 1            24270.0  Computers & Accessories  Accessories & Peripherals
# 2            24269.0  Computers & Accessories  Accessories & Peripherals
# 3            24269.0  Computers & Accessories  Accessories & Peripherals
# 4            24270.0  Computers & Accessories  Accessories & Peripherals
# ...              ...                      ...                        ...
# 151804        6987.0           Home & Kitchen  Kitchen & Home Appliances
# 151805        6987.0           Home & Kitchen  Kitchen & Home Appliances
# 151806        6987.0           Home & Kitchen  Kitchen & Home Appliances
# 151807        6987.0           Home & Kitchen  Kitchen & Home Appliances
# 151808        6987.0           Home & Kitchen  Kitchen & Home Appliances
#
#          rating_score  difference_price    neg    neu    pos  compound
# 0       Above Average             700.0  0.032  0.744  0.224    0.9033
# 1       Above Average             700.0  0.032  0.744  0.224    0.9033
# 2       Above Average             700.0  0.032  0.744  0.224    0.9033
# 3       Above Average             700.0  0.032  0.744  0.224    0.9033
# 4       Above Average             700.0  0.032  0.744  0.224    0.9033
# ...               ...               ...    ...    ...    ...       ...
# 151804  Above Average             827.0  0.007  0.847  0.146    0.9915
# 151805  Above Average             827.0  0.007  0.847  0.146    0.9915
# 151806  Above Average             827.0  0.007  0.847  0.146    0.9915
# 151807  Above Average             827.0  0.007  0.847  0.146    0.9915
# 151808  Above Average             827.0  0.007  0.847  0.146    0.9915
#
# [151809 rows x 18 columns]

# %%
product_ids1 = df_clean.product_id.unique()

# %%
len(product_ids1)
# Out:
# 1342

# %%
feature_product = data_clean[['product_id', 'neg', 'neu', 'pos', 'compound']]

# %%
feature_product.drop_duplicates(inplace=True)
len(feature_product)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6332\756524890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_product.drop_duplicates(inplace=True)
# 1351

# %%
product_ids2 = feature_product.product_id.unique()

# %%
for id in product_ids2:
    if id not in product_ids1:
        print(id)
# Out:
# B08Y1TFSP6
# B08Y1SJVV5
# B0B9XN9S3W
# B0981XSZJ7
# B08Y5KXR6Z
# B084N18QZY
# B07T9FV9YP
# B097R2V1W8
# B07MKMFKPG

# %%
df_clean = merge_dataframe([df_clean, feature_product], on='product_id')

# %%
df_clean
# Out:
#        product_id                                       product_name  \
# 0      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4      B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# ...           ...                                                ...
# 11402  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 11403  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 11404  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 11405  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
# 11406  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#        discounted_price  actual_price  discount_percentage  rating  \
# 0                 399.0        1099.0                 0.64     4.2
# 1                 399.0        1099.0                 0.64     4.2
# 2                 399.0        1099.0                 0.64     4.2
# 3                 399.0        1099.0                 0.64     4.2
# 4                 399.0        1099.0                 0.64     4.2
# ...                 ...           ...                  ...     ...
# 11402            2863.0        3690.0                 0.22     4.3
# 11403            2863.0        3690.0                 0.22     4.3
# 11404            2863.0        3690.0                 0.22     4.3
# 11405            2863.0        3690.0                 0.22     4.3
# 11406            2863.0        3690.0                 0.22     4.3
#
#        rating_count                                      about_product  \
# 0           24269.0  High Compatibility : Compatible With iPhone 12...
# 1           24269.0  High Compatibility : Compatible With iPhone 12...
# 2           24269.0  High Compatibility : Compatible With iPhone 12...
# 3           24269.0  High Compatibility : Compatible With iPhone 12...
# 4           24269.0  High Compatibility : Compatible With iPhone 12...
# ...             ...                                                ...
# 11402        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 11403        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 11404        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 11405        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
# 11406        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                             user_id         user_name  ...  \
# 0      AG3D6O4STAQKAY2UVGEUV46KN35Q             Manav  ...
# 1      AHMY5CWJMMK5BJRBBSNLYT3ONILA      Adarsh gupta  ...
# 2      AHCTC6ULH4XB6YHDY6PCH2R772LQ           Sundeep  ...
# 3      AGYHHIERNXKA6P5T7CZLXKVPT7IQ    S.Sayeed Ahmed  ...
# 4      AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q    jaspreet singh  ...
# ...                             ...               ...  ...
# 11402  AHXCDNSXAESERITAFELQABFVNLCA           PARDEEP  ...
# 11403  AGRZD6CHLCUNOLMMIMIHUCG7PIFA  Anindya Pramanik  ...
# 11404  AFQZVGSOSOJHKFQQMCEI4725QEKQ       Vikas Singh  ...
# 11405  AEALVGXXIP46OZVXKRUXSDWZJMEA   Harshada Pimple  ...
# 11406  AGEFL3AY7YXEFZA4ZJU3LP7K7OJQ            Saw a.  ...
#
#                                                 img_link  \
# 0      https://m.media-amazon.com/images/W/WEBP_40237...
# 1      https://m.media-amazon.com/images/W/WEBP_40237...
# 2      https://m.media-amazon.com/images/W/WEBP_40237...
# 3      https://m.media-amazon.com/images/W/WEBP_40237...
# 4      https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                  ...
# 11402  https://m.media-amazon.com/images/W/WEBP_40237...
# 11403  https://m.media-amazon.com/images/W/WEBP_40237...
# 11404  https://m.media-amazon.com/images/W/WEBP_40237...
# 11405  https://m.media-amazon.com/images/W/WEBP_40237...
# 11406  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                             product_link  \
# 0      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 3      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4      https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# ...                                                  ...
# 11402  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 11403  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 11404  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 11405  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# 11406  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
#                      category_1                  category_2   rating_score  \
# 0       Computers & Accessories   Accessories & Peripherals  Above Average
# 1       Computers & Accessories   Accessories & Peripherals  Above Average
# 2       Computers & Accessories   Accessories & Peripherals  Above Average
# 3       Computers & Accessories   Accessories & Peripherals  Above Average
# 4       Computers & Accessories   Accessories & Peripherals  Above Average
# ...                         ...                         ...            ...
# 11402            Home & Kitchen   Kitchen & Home Appliances  Above Average
# 11403            Home & Kitchen   Kitchen & Home Appliances  Above Average
# 11404            Home & Kitchen   Kitchen & Home Appliances  Above Average
# 11405            Home & Kitchen   Kitchen & Home Appliances  Above Average
# 11406            Home & Kitchen   Kitchen & Home Appliances  Above Average
#
#       price_difference    neg    neu    pos  compound
# 0                700.0  0.032  0.744  0.224    0.9033
# 1                700.0  0.032  0.744  0.224    0.9033
# 2                700.0  0.032  0.744  0.224    0.9033
# 3                700.0  0.032  0.744  0.224    0.9033
# 4                700.0  0.032  0.744  0.224    0.9033
# ...                ...    ...    ...    ...       ...
# 11402            827.0  0.007  0.847  0.146    0.9915
# 11403            827.0  0.007  0.847  0.146    0.9915
# 11404            827.0  0.007  0.847  0.146    0.9915
# 11405            827.0  0.007  0.847  0.146    0.9915
# 11406            827.0  0.007  0.847  0.146    0.9915
#
# [11407 rows x 23 columns]

# %%
df_clean.columns
# Out:
# Index(['product_id', 'product_name', 'discounted_price', 'actual_price',
#        'discount_percentage', 'rating', 'rating_count', 'about_product',
#        'user_id', 'user_name', 'review_id', 'review_title', 'review_content',
#        'img_link', 'product_link', 'category_1', 'category_2', 'rating_score',
#        'price_difference', 'neg', 'neu', 'pos', 'compound'],
#       dtype='object')

# %%
df_clean.loc[df_clean.product_id=='B07JW9H4J1']
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 3     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 5     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 6     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 7     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2834  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2835  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2836  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2837  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2838  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2839  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2840  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 2841  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4731  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4732  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4733  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4734  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4735  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4736  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4737  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 4738  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 1     High Compatibility : Compatible With iPhone 12...
# 2     High Compatibility : Compatible With iPhone 12...
# 3     High Compatibility : Compatible With iPhone 12...
# 4     High Compatibility : Compatible With iPhone 12...
# 5     High Compatibility : Compatible With iPhone 12...
# 6     High Compatibility : Compatible With iPhone 12...
# 7     High Compatibility : Compatible With iPhone 12...
# 2834  High Compatibility : Compatible With iPhone 12...
# 2835  High Compatibility : Compatible With iPhone 12...
# 2836  High Compatibility : Compatible With iPhone 12...
# 2837  High Compatibility : Compatible With iPhone 12...
# 2838  High Compatibility : Compatible With iPhone 12...
# 2839  High Compatibility : Compatible With iPhone 12...
# 2840  High Compatibility : Compatible With iPhone 12...
# 2841  High Compatibility : Compatible With iPhone 12...
# 4731  High Compatibility : Compatible With iPhone 12...
# 4732  High Compatibility : Compatible With iPhone 12...
# 4733  High Compatibility : Compatible With iPhone 12...
# 4734  High Compatibility : Compatible With iPhone 12...
# 4735  High Compatibility : Compatible With iPhone 12...
# 4736  High Compatibility : Compatible With iPhone 12...
# 4737  High Compatibility : Compatible With iPhone 12...
# 4738  High Compatibility : Compatible With iPhone 12...
#
#                     category_1                  category_2  discounted_price  \
# 0      Computers & Accessories   Accessories & Peripherals             399.0
# 1      Computers & Accessories   Accessories & Peripherals             399.0
# 2      Computers & Accessories   Accessories & Peripherals             399.0
# 3      Computers & Accessories   Accessories & Peripherals             399.0
# 4      Computers & Accessories   Accessories & Peripherals             399.0
# 5      Computers & Accessories   Accessories & Peripherals             399.0
# 6      Computers & Accessories   Accessories & Peripherals             399.0
# 7      Computers & Accessories   Accessories & Peripherals             399.0
# 2834   Computers & Accessories   Accessories & Peripherals             399.0
# 2835   Computers & Accessories   Accessories & Peripherals             399.0
# 2836   Computers & Accessories   Accessories & Peripherals             399.0
# 2837   Computers & Accessories   Accessories & Peripherals             399.0
# 2838   Computers & Accessories   Accessories & Peripherals             399.0
# 2839   Computers & Accessories   Accessories & Peripherals             399.0
# 2840   Computers & Accessories   Accessories & Peripherals             399.0
# 2841   Computers & Accessories   Accessories & Peripherals             399.0
# 4731   Computers & Accessories   Accessories & Peripherals             399.0
# 4732   Computers & Accessories   Accessories & Peripherals             399.0
# 4733   Computers & Accessories   Accessories & Peripherals             399.0
# 4734   Computers & Accessories   Accessories & Peripherals             399.0
# 4735   Computers & Accessories   Accessories & Peripherals             399.0
# 4736   Computers & Accessories   Accessories & Peripherals             399.0
# 4737   Computers & Accessories   Accessories & Peripherals             399.0
# 4738   Computers & Accessories   Accessories & Peripherals             399.0
#
#       actual_price  discount_percentage  price_difference  rating  ...  \
# 0           1099.0                 0.64             700.0     4.2  ...
# 1           1099.0                 0.64             700.0     4.2  ...
# 2           1099.0                 0.64             700.0     4.2  ...
# 3           1099.0                 0.64             700.0     4.2  ...
# 4           1099.0                 0.64             700.0     4.2  ...
# 5           1099.0                 0.64             700.0     4.2  ...
# 6           1099.0                 0.64             700.0     4.2  ...
# 7           1099.0                 0.64             700.0     4.2  ...
# 2834        1099.0                 0.64             700.0     4.2  ...
# 2835        1099.0                 0.64             700.0     4.2  ...
# 2836        1099.0                 0.64             700.0     4.2  ...
# 2837        1099.0                 0.64             700.0     4.2  ...
# 2838        1099.0                 0.64             700.0     4.2  ...
# 2839        1099.0                 0.64             700.0     4.2  ...
# 2840        1099.0                 0.64             700.0     4.2  ...
# 2841        1099.0                 0.64             700.0     4.2  ...
# 4731        1099.0                 0.64             700.0     4.2  ...
# 4732        1099.0                 0.64             700.0     4.2  ...
# 4733        1099.0                 0.64             700.0     4.2  ...
# 4734        1099.0                 0.64             700.0     4.2  ...
# 4735        1099.0                 0.64             700.0     4.2  ...
# 4736        1099.0                 0.64             700.0     4.2  ...
# 4737        1099.0                 0.64             700.0     4.2  ...
# 4738        1099.0                 0.64             700.0     4.2  ...
#
#            user_name                                          review_id  \
# 0              Manav  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1       Adarsh gupta  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2            Sundeep  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 3     S.Sayeed Ahmed  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4     jaspreet singh  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 5         Khaja moin  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 6              Anand  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 7         S.ARUMUGAM  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2834           Manav  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2835    Adarsh gupta  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2836         Sundeep  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2837  S.Sayeed Ahmed  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2838  jaspreet singh  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2839      Khaja moin  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2840           Anand  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 2841      S.ARUMUGAM  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4731           Manav  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4732    Adarsh gupta  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4733         Sundeep  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4734  S.Sayeed Ahmed  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4735  jaspreet singh  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4736      Khaja moin  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4737           Anand  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 4738      S.ARUMUGAM  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     Satisfied,Charging is really fast,Value for mo...
# 2     Satisfied,Charging is really fast,Value for mo...
# 3     Satisfied,Charging is really fast,Value for mo...
# 4     Satisfied,Charging is really fast,Value for mo...
# 5     Satisfied,Charging is really fast,Value for mo...
# 6     Satisfied,Charging is really fast,Value for mo...
# 7     Satisfied,Charging is really fast,Value for mo...
# 2834  Satisfied,Charging is really fast,Value for mo...
# 2835  Satisfied,Charging is really fast,Value for mo...
# 2836  Satisfied,Charging is really fast,Value for mo...
# 2837  Satisfied,Charging is really fast,Value for mo...
# 2838  Satisfied,Charging is really fast,Value for mo...
# 2839  Satisfied,Charging is really fast,Value for mo...
# 2840  Satisfied,Charging is really fast,Value for mo...
# 2841  Satisfied,Charging is really fast,Value for mo...
# 4731  Satisfied,Charging is really fast,Value for mo...
# 4732  Satisfied,Charging is really fast,Value for mo...
# 4733  Satisfied,Charging is really fast,Value for mo...
# 4734  Satisfied,Charging is really fast,Value for mo...
# 4735  Satisfied,Charging is really fast,Value for mo...
# 4736  Satisfied,Charging is really fast,Value for mo...
# 4737  Satisfied,Charging is really fast,Value for mo...
# 4738  Satisfied,Charging is really fast,Value for mo...
#
#                                          review_content    neg    neu    pos  \
# 0     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 1     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 3     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 5     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 6     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 7     Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2834  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2835  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2836  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2837  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2838  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2839  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2840  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 2841  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4731  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4732  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4733  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4734  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4735  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4736  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4737  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
# 4738  Looks durable Charging is fine tooNo complains...  0.032  0.744  0.224
#
#       compound                                           img_link  \
# 0       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 1       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 2       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 3       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 5       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 6       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 7       0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 2834    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2835    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2836    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2837    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2838    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2839    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2840    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 2841    0.9033  https://m.media-amazon.com/images/I/51UsScvHQN...
# 4731    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4732    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4733    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4734    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4735    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4736    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4737    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
# 4738    0.9033  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 3     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 5     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 6     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 7     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2834  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2835  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2836  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2837  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2838  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2839  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2840  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 2841  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4731  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4732  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4733  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4734  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4735  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4736  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4737  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 4738  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
#
# [24 rows x 23 columns]

# %%
column_position = ['product_id','product_name','about_product','category_1','category_2','discounted_price','actual_price','discount_percentage', 
                   'price_difference','rating', 'rating_count', 'rating_score', 'neg','neu','pos','compound',
                   'user_id','user_name', 'img_link','product_link']
df_clean = df_clean[column_position]

# %%
# take only user with a number of rating at least rating_threshold
rating_threshold = 10 #only user with 10 ratings above will be fed to recommendation system
train_df =
# Out:
# 8886

# %%
product = df[['product_id', 'about_product']]

# %%
product = product.drop_duplicates()
